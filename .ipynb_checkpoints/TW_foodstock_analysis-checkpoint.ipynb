# %%
# Import required libraries
import yfinance as yf
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from statsmodels.formula.api import ols

# Set notebook display options
# %matplotlib inline

# Define stock symbols
food_stocks = ["1216.TW", "1203.TW", "1234.TW", "1215.TW", "1220.TW"]
start_date = "2020-01-01"
end_date = "2024-01-01"

# Download data for Taiwan Index Futures
taifex = yf.download("^TWII", start=start_date, end=end_date)

# Download data for food stocks
food_data = {ticker: yf.download(ticker, start=start_date, end=end_date) for ticker in food_stocks}

# Calculate daily returns
taifex['Daily Return'] = taifex['Close'].pct_change()
for ticker, data in food_data.items():
    food_data[ticker]['Daily Return'] = data['Close'].pct_change()

# Combine data into one DataFrame
combined = pd.DataFrame({'Taifex Return': taifex['Daily Return']})
for ticker, data in food_data.items():
    combined[ticker] = data['Daily Return']

# Drop NA values
combined = combined.dropna()

# Compute correlation matrix
correlation = combined.corr()
print("Correlation Matrix:\n", correlation)

# Visualize correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(correlation, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Matrix between Taifex and Food Stocks")
plt.show()

# Sanitize column names
sanitized_columns = {ticker: "TW_" + ticker.split('.')[0] for ticker in food_stocks}
combined.rename(columns=sanitized_columns, inplace=True)
combined.rename(columns={'Taifex Return': 'Taifex_Return'}, inplace=True)
print(combined)
print(sanitized_columns)

# Perform regression analysis and plot cumulative returns for each stock
for original_name, sanitized_name in sanitized_columns.items():
    # Construct the regression formula
    formula = f"{sanitized_name} ~ Taifex_Return"
    model = ols(formula, data=combined).fit()
    
    # Print regression summary
    print(f"Regression Analysis for {original_name}:")
    print(model.summary())

    # Cumulative return plot
    cumulative = combined[['Taifex_Return', sanitized_name]].cumsum()
    cumulative.plot(figsize=(10, 6))
    plt.title(f"Cumulative Returns: Taifex vs {original_name}")
    plt.xlabel("Date")
    plt.ylabel("Cumulative Return")
    plt.legend(["Taifex", original_name])
    plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Correlation Matrix:
#                 Taifex Return   1216.TW   1203.TW   1234.TW   1215.TW   1220.TW
# Taifex Return       1.000000  0.461786  0.236716  0.522553  0.401998  0.324338
# 1216.TW             0.461786  1.000000  0.151051  0.329989  0.258820  0.197093
# 1203.TW             0.236716  0.151051  1.000000  0.205276  0.165320  0.158524
# 1234.TW             0.522553  0.329989  0.205276  1.000000  0.350351  0.357753
# 1215.TW             0.401998  0.258820  0.165320  0.350351  1.000000  0.251138
# 1220.TW             0.324338  0.197093  0.158524  0.357753  0.251138  1.000000
#             Taifex_Return   TW_1216   TW_1203   TW_1234   TW_1215   TW_1220
# Date
# 2020-01-03       0.000822  0.008086  0.000000  0.000000 -0.004532  0.004739
# 2020-01-06      -0.012970 -0.012032 -0.005495 -0.001529 -0.013657  0.000000
# 2020-01-07      -0.006110 -0.006766 -0.001841  0.000000  0.009231  0.004717
# 2020-01-08      -0.005321 -0.010899  0.001845 -0.001532 -0.007622 -0.014085
# 2020-01-09       0.012992  0.011019 -0.001841  0.001534  0.001536  0.004762
# ...                   ...       ...       ...       ...       ...       ...
# 2023-12-25       0.000467  0.004104  0.003745  0.000000 -0.005155 -0.010417
# 2023-12-26       0.008344  0.001362  0.027985  0.000000  0.000000  0.003509
# 2023-12-27       0.007874  0.005442  0.014519  0.002494 -0.005181 -0.003497
# 2023-12-28       0.001055  0.004059  0.001789  0.001244  0.004167  0.010526
# 2023-12-29       0.001141  0.004043  0.016071  0.006211 -0.003112 -0.003472
#
# [972 rows x 6 columns]
# {'1216.TW': 'TW_1216', '1203.TW': 'TW_1203', '1234.TW': 'TW_1234', '1215.TW': 'TW_1215', '1220.TW': 'TW_1220'}
# Regression Analysis for 1216.TW:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                TW_1216   R-squared:                       0.213
# Model:                            OLS   Adj. R-squared:                  0.212
# Method:                 Least Squares   F-statistic:                     262.9
# Date:                Mon, 23 Dec 2024   Prob (F-statistic):           1.68e-52
# Time:                        15:31:13   Log-Likelihood:                 3169.8
# No. Observations:                 972   AIC:                            -6336.
# Df Residuals:                     970   BIC:                            -6326.
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept       6.49e-05      0.000      0.218      0.828      -0.001       0.001
# Taifex_Return     0.4242      0.026     16.215      0.000       0.373       0.475
# ==============================================================================
# Omnibus:                       87.763   Durbin-Watson:                   2.164
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              409.090
# Skew:                           0.263   Prob(JB):                     1.47e-89
# Kurtosis:                       6.134   Cond. No.                         87.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 1216.TW
# TW_1216
# Regression Analysis for 1203.TW:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                TW_1203   R-squared:                       0.056
# Model:                            OLS   Adj. R-squared:                  0.055
# Method:                 Least Squares   F-statistic:                     57.58
# Date:                Mon, 23 Dec 2024   Prob (F-statistic):           7.60e-14
# Time:                        15:31:13   Log-Likelihood:                 2957.1
# No. Observations:                 972   AIC:                            -5910.
# Df Residuals:                     970   BIC:                            -5901.
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         0.0008      0.000      2.260      0.024       0.000       0.002
# Taifex_Return     0.2471      0.033      7.588      0.000       0.183       0.311
# ==============================================================================
# Omnibus:                      443.704   Durbin-Watson:                   2.364
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8418.639
# Skew:                           1.612   Prob(JB):                         0.00
# Kurtosis:                      17.052   Cond. No.                         87.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 1203.TW
# TW_1203
# Regression Analysis for 1234.TW:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                TW_1234   R-squared:                       0.273
# Model:                            OLS   Adj. R-squared:                  0.272
# Method:                 Least Squares   F-statistic:                     364.4
# Date:                Mon, 23 Dec 2024   Prob (F-statistic):           3.28e-69
# Time:                        15:31:13   Log-Likelihood:                 3573.0
# No. Observations:                 972   AIC:                            -7142.
# Df Residuals:                     970   BIC:                            -7132.
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         0.0003      0.000      1.501      0.134   -9.09e-05       0.001
# Taifex_Return     0.3298      0.017     19.088      0.000       0.296       0.364
# ==============================================================================
# Omnibus:                      170.424   Durbin-Watson:                   2.155
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1788.083
# Skew:                           0.452   Prob(JB):                         0.00
# Kurtosis:                       9.583   Cond. No.                         87.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 1234.TW
# TW_1234
# Regression Analysis for 1215.TW:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                TW_1215   R-squared:                       0.162
# Model:                            OLS   Adj. R-squared:                  0.161
# Method:                 Least Squares   F-statistic:                     187.0
# Date:                Mon, 23 Dec 2024   Prob (F-statistic):           4.73e-39
# Time:                        15:31:13   Log-Likelihood:                 3072.8
# No. Observations:                 972   AIC:                            -6142.
# Df Residuals:                     970   BIC:                            -6132.
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         0.0005      0.000      1.660      0.097   -9.95e-05       0.001
# Taifex_Return     0.3953      0.029     13.674      0.000       0.339       0.452
# ==============================================================================
# Omnibus:                      355.300   Durbin-Watson:                   1.987
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3788.491
# Skew:                           1.358   Prob(JB):                         0.00
# Kurtosis:                      12.283   Cond. No.                         87.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 1215.TW
# TW_1215
# Regression Analysis for 1220.TW:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                TW_1220   R-squared:                       0.105
# Model:                            OLS   Adj. R-squared:                  0.104
# Method:                 Least Squares   F-statistic:                     114.0
# Date:                Mon, 23 Dec 2024   Prob (F-statistic):           3.03e-25
# Time:                        15:31:13   Log-Likelihood:                 2668.1
# No. Observations:                 972   AIC:                            -5332.
# Df Residuals:                     970   BIC:                            -5322.
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         0.0004      0.000      0.852      0.395      -0.001       0.001
# Taifex_Return     0.4681      0.044     10.679      0.000       0.382       0.554
# ==============================================================================
# Omnibus:                      400.194   Durbin-Watson:                   1.840
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6499.287
# Skew:                           1.444   Prob(JB):                         0.00
# Kurtosis:                      15.334   Cond. No.                         87.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 1220.TW
# TW_1220

# %%
# Plot all stocks cumulative returns together
cumulative_all = combined.cumsum()
plt.figure(figsize=(12, 8))
for col in sanitized_columns.values():
    plt.plot(cumulative_all.index, cumulative_all[col], label=col)
plt.plot(cumulative_all.index, cumulative_all['Taifex_Return'], label='Taifex_Return', linestyle='--')
plt.title("Cumulative Returns: All Stocks and Taifex")
plt.xlabel("Date")
plt.ylabel("Cumulative Return")
plt.legend()
plt.show()
